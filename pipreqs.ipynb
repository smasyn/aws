# %%
pip install pipreqs
pipreqs /path/to/project

# %%
# %pip install pipreqs
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pipreqs
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/798.3 kB ? eta -:--:--
#    ---- ----------------------------------- 92.2/798.3 kB 2.6 MB/s eta 0:00:01
#    --------- ------------------------------ 194.6/798.3 kB 2.4 MB/s eta 0:00:01
#    -------------- ------------------------- 286.7/798.3 kB 2.2 MB/s eta 0:00:01
#    ------------------- -------------------- 389.1/798.3 kB 2.2 MB/s eta 0:00:01
#    ------------------------ --------------- 481.3/798.3 kB 2.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 583.7/798.3 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 686.1/798.3 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  788.5/798.3 kB 2.2 MB/s eta 0:00:01
# ...

# %%
% pipreqs c:/gebruiker/onedrive/coursera/python/llm/aws
# Out:
# UsageError: Line magic function `%` not found.
